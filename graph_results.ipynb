# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# # MCTS Num of simulations required to beat MoHex

# %%
data = {1: 1,2:1,3:2}

plt.yscale("log")

plt.plot(data.keys(),data.values())
plt.show()
